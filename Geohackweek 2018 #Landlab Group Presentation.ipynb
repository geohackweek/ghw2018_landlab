# %% [markdown]
# ## Curriculum building for geo-spatio-temporal analysis
#
# ### Geohackweek 2018   9/14/2018
#
# ### www.github.com/geohackweek/ghw2018_landlab
#
# Steven Walters
#
# Rose Hilmo
#
# Helen Deweese
#
# Christina Bandaragoda

# %% [markdown]
# ## Landlab Tutorials for Earth Science Applications
#
# Steven Walters
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Personal Pedagogic Goals
#  - Introduce (grad-level?) earth science students to open-source geospatial analytic approaches and resources.  Explore how these tools take capabilities beyond ArcGIS, ENVI, etc.
#
#  - Illustrate applications of interest to the students (i.e., now that I got it, what do I do with it?!)
#
#  - For my experience at Geohackweek, begin to understand all this stuff myself!

# %% [markdown]
# ## Practice Tutorial: shallow landslide model to explore changes in forest cover from fire at a subcatchment within the study area
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Landlab Model Overview
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Landlab Landslide Probability Results
# ### Fisher Creek watershed, North Cascades National Park
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Building a blue whale call detector in python
#
# #### Rose Hilmo

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
#  - Numpy, Scipy, Matplotlib
#  - Reading audio (.wav) files
#  - Visualizing acoustic data as timeseries and spectrograms.

# %% [markdown]
# ## 3.0 Data Science Results
#
# Viewing whale calls: strong and weak whale calls as timeseries and spectrograms. Observe that weak calls are more distinguishable on spectrograms than in waveform.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 4.0 Spectogram Cross-Correlation
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## VIsualize the spectogram
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Zoomed detection scores for weak and strong calls
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Xarray input and output
#
# ### Helen Deweese

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Personal Pedagogic Goals
#  - Introduce (grad-level?) earth science students to open-source geospatial analytic approaches and resources.  Explore how these tools take capabilities beyond ArcGIS, ENVI, etc.
#
#  - Illustrate applications of interest to the students (i.e., now that I got it, what do I do with it?!)
#
#  - For my experience at Geohackweek, begin to understand all this stuff myself!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
